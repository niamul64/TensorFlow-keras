# %%
from tensorflow.keras.models import load_model
import numpy as np
from PIL import Image as image
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import Input,Dense, Flatten , Activation, BatchNormalization, Conv2D, MaxPool2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.models import Sequential
from glob import glob

saved_model = load_model("vggclf.h5")\
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
from keras.preprocessing import image
img = image.load_img("D:\github uploads\TensorFlow-keras\predict image\k.jpg", target_size = (224,224))
img = np.asarray(img)
plt.imshow(img)
img = np.expand_dims(img, axis = 0)

# %%
from keras.models import load_model
saved_model = load_model("./vggclf.h5")
output = saved_model.predict(img)
if output[0][0] > output[0][1]:
    print("No one washing his hand")
    print(output)
else:
    print("washing")
    print(output)
# Out:
# washing
# [[0. 1.]]

# %%
 
# Opens the Video file
cap= cv2.VideoCapture("Videos/2020-06-30_10-47-58_camera101.mp4")
i=0
if cap.isOpened() == False:
    print('error')
    
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == False:
        break

    #cv2.imwrite('frame/kang'+str(i)+'.jpg',frame)
    if ret == True:

        
        cv2.imshow('frame', frame)
        cv2.imwrite('predict image/kang'+str(i)+'.jpg',frame)
        
        img = image.load_img('predict image/kang'+str(i)+'.jpg', target_size = (224,224))
        img = np.asarray(img)
        output = saved_model.predict(img)
        plt.imshow(img)
        img = np.expand_dims(img, axis = 0)
#         output = saved_model.predict(img)

        print(output)
        if cv2.waitKey() and 0xFF == ord('q'):
            break
    i+=1
 
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-22080764f8c2> in <module>
#      19         img = image.load_img('predict image/kang'+str(i)+'.jpg', target_size = (224,224))
#      20         img = np.asarray(img)
# ---> 21         output = saved_model.predict(img)
#      22         plt.imshow(img)
#      23         img = np.expand_dims(img, axis = 0)
#
# ~\.conda\envs\python-cvcourse\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1484     # Validate and standardize user data.
#    1485     x, _, _ = self._standardize_user_data(
# -> 1486         x, check_steps=True, steps_name='steps', steps=steps)
#    1487
#    1488     if context.executing_eagerly():
#
# ...
